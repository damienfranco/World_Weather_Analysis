# %% [markdown]
# # Challege 1 - Get the weather descrition and amount of preciptiation for each city

# %%
# Import dependencies
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitudes and longtitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longtitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding cities
cities = []

# Identify nearesty city for longitude and latitude combinations
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 771

# %%
# Import request library
import requests

from datetime import datetime

from config import weather_api_key

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval")
print("-" * 25)

# Create a counter
record_count = 1
set_count = 1
for index, city in enumerate(cities):
    if(index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 1
        
    city_url = f'{url}&q={city.replace(" ", "+")}'
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        # Pares out in the max item, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_snow_inches = 0
            
        # Append the city information into city_data
        city_data.append(
        {
            "City": city,
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Current Description": city_weather_description,
            "Rain (inches)": city_rain_inches,
            "Snow (inches)": city_snow_inches,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country
        })
    except:
        print("City not found. Skipping...")
        pass
# Indicate that the Data Loading is complete
print("-" * 20)
print("Data Retrieval Complete")
print("-" * 20)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | bengkulu
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | knin
# Processing Record 4 of Set 1 | pacific grove
# Processing Record 5 of Set 1 | yenagoa
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | east london
# Processing Record 9 of Set 1 | adrar
# Processing Record 10 of Set 1 | honningsvag
# Processing Record 11 of Set 1 | hithadhoo
# Processing Record 12 of Set 1 | cayenne
# Processing Record 13 of Set 1 | somerset east
# Processing Record 14 of Set 1 | carnarvon
# Processing Record 15 of Set 1 | ternate
# Processing Record 16 of Set 1 | calama
# Processing Record 17 of Set 1 | arlit
# Processing Record 18 of Set 1 | tosya
# Processing Record 19 of Set 1 | thompson
# Processing Record 20 of Set 1 | richards bay
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | shakiso
# Processing Record 23 of Set 1 | vilhena
# Processing Record 24 of Set 1 | ribeira brava
# Processing Record 25 of Set 1 | renukut
# Processing Record 26 of Set 1 | airai
# Processing Record 27 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 1 | ocos
# Processing Record 29 of Set 1 | bodden town
# Processing Record 30 of Set 1 | hobart
# Processing Record 31 of Set 1 | lorengau
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | sechura
# Processing Record 35 of Set 1 | balimo
# City not found. Skipping...
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | omsukchan
# Processing Record 38 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 1 | hambantota
# Processing Record 40 of Set 1 | gryazi
# Processing Record 41 of Set 1 | egvekinot
# Processing Record 42 of Set 1 | linxia
# Processing Record 43 of Set 1 | oriximina
# Processing Record 44 of Set 1 | novyy yegorlyk
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | khatanga
# Processing Record 47 of Set 1 | santa isabel
# Processing Record 48 of Set 1 | mildura
# Processing Record 49 of Set 1 | aybak
# City not found. Skipping...
# Processing Record 50 of Set 1 | rongcheng
# Processing Record 1 of Set 2 | saint-philippe
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | codrington
# Processing Record 4 of Set 2 | hilo
# Processing Record 5 of Set 2 | hirara
# Processing Record 6 of Set 2 | port alfred
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | dunedin
# Processing Record 9 of Set 2 | bandarbeyla
# Processing Record 10 of Set 2 | iqaluit
# Processing Record 11 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 2 | salym
# Processing Record 13 of Set 2 | dikson
# Processing Record 14 of Set 2 | arraial do cabo
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | cherskiy
# Processing Record 19 of Set 2 | tocopilla
# Processing Record 20 of Set 2 | kaitangata
# Processing Record 21 of Set 2 | pevek
# Processing Record 22 of Set 2 | kloulklubed
# Processing Record 23 of Set 2 | pozzallo
# Processing Record 24 of Set 2 | puerto ayora
# Processing Record 25 of Set 2 | ponta do sol
# Processing Record 26 of Set 2 | lagoa
# Processing Record 27 of Set 2 | tuktoyaktuk
# Processing Record 28 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 2 | indramayu
# Processing Record 30 of Set 2 | alofi
# Processing Record 31 of Set 2 | kapaa
# Processing Record 32 of Set 2 | yellowknife
# Processing Record 33 of Set 2 | alpena
# Processing Record 34 of Set 2 | lanzhou
# Processing Record 35 of Set 2 | seminole
# Processing Record 36 of Set 2 | bissendorf
# Processing Record 37 of Set 2 | dekoa
# City not found. Skipping...
# Processing Record 38 of Set 2 | kushmurun
# Processing Record 39 of Set 2 | beyneu
# Processing Record 40 of Set 2 | lebu
# Processing Record 41 of Set 2 | college
# Processing Record 42 of Set 2 | mangaratiba
# Processing Record 43 of Set 2 | kruisfontein
# Processing Record 44 of Set 2 | pangnirtung
# Processing Record 45 of Set 2 | varska
# City not found. Skipping...
# Processing Record 46 of Set 2 | san ignacio
# Processing Record 47 of Set 2 | praia da vitoria
# Processing Record 48 of Set 2 | yar-sale
# Processing Record 49 of Set 2 | lompoc
# Processing Record 50 of Set 2 | erdenet
# Processing Record 1 of Set 3 | kalga
# Processing Record 2 of Set 3 | burnie
# Processing Record 3 of Set 3 | mar del plata
# Processing Record 4 of Set 3 | stekolnyy
# City not found. Skipping...
# Processing Record 5 of Set 3 | tiksi
# Processing Record 6 of Set 3 | sitka
# Processing Record 7 of Set 3 | los llanos de aridane
# Processing Record 8 of Set 3 | ostrovnoy
# Processing Record 9 of Set 3 | saint george
# Processing Record 10 of Set 3 | rosarito
# Processing Record 11 of Set 3 | provideniya
# Processing Record 12 of Set 3 | mayo
# Processing Record 13 of Set 3 | vaini
# Processing Record 14 of Set 3 | eureka
# Processing Record 15 of Set 3 | cabo san lucas
# Processing Record 16 of Set 3 | qaqortoq
# Processing Record 17 of Set 3 | odweyne
# Processing Record 18 of Set 3 | busselton
# Processing Record 19 of Set 3 | victoria
# Processing Record 20 of Set 3 | ueki
# Processing Record 21 of Set 3 | asau
# Processing Record 22 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 3 | tasiilaq
# Processing Record 24 of Set 3 | kendari
# Processing Record 25 of Set 3 | namatanai
# Processing Record 26 of Set 3 | meulaboh
# Processing Record 27 of Set 3 | havelock
# Processing Record 28 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 3 | hofn
# Processing Record 30 of Set 3 | coahuayana
# Processing Record 31 of Set 3 | wakkanai
# Processing Record 32 of Set 3 | hasaki
# Processing Record 33 of Set 3 | ruwi
# Processing Record 34 of Set 3 | bang saphan
# Processing Record 35 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 3 | meadow lake
# Processing Record 37 of Set 3 | upernavik
# Processing Record 38 of Set 3 | christchurch
# Processing Record 39 of Set 3 | chuy
# Processing Record 40 of Set 3 | fortuna
# Processing Record 41 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 3 | bambous virieux
# Processing Record 43 of Set 3 | buala
# Processing Record 44 of Set 3 | sterling
# Processing Record 45 of Set 3 | bonavista
# Processing Record 46 of Set 3 | okhotsk
# Processing Record 47 of Set 3 | banda aceh
# Processing Record 48 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 49 of Set 3 | ankang
# Processing Record 50 of Set 3 | goma
# Processing Record 1 of Set 4 | bahir dar
# Processing Record 2 of Set 4 | taos
# Processing Record 3 of Set 4 | tazovskiy
# Processing Record 4 of Set 4 | ahipara
# Processing Record 5 of Set 4 | glace bay
# Processing Record 6 of Set 4 | anadyr
# Processing Record 7 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 8 of Set 4 | matay
# Processing Record 9 of Set 4 | vao
# Processing Record 10 of Set 4 | takoradi
# Processing Record 11 of Set 4 | tottori
# Processing Record 12 of Set 4 | coihaique
# Processing Record 13 of Set 4 | agadez
# Processing Record 14 of Set 4 | camacha
# Processing Record 15 of Set 4 | tumut
# Processing Record 16 of Set 4 | charlestown
# Processing Record 17 of Set 4 | port hedland
# Processing Record 18 of Set 4 | gualaquiza
# Processing Record 19 of Set 4 | lahat
# Processing Record 20 of Set 4 | longonjo
# Processing Record 21 of Set 4 | ribeira grande
# Processing Record 22 of Set 4 | butaritari
# Processing Record 23 of Set 4 | volgorechensk
# Processing Record 24 of Set 4 | ixtapa
# Processing Record 25 of Set 4 | eydhafushi
# Processing Record 26 of Set 4 | mount isa
# Processing Record 27 of Set 4 | pochutla
# Processing Record 28 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 4 | gamba
# Processing Record 30 of Set 4 | hervey bay
# Processing Record 31 of Set 4 | pisco
# Processing Record 32 of Set 4 | kodiak
# Processing Record 33 of Set 4 | poya
# Processing Record 34 of Set 4 | yurino
# Processing Record 35 of Set 4 | bredasdorp
# Processing Record 36 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 4 | nushki
# Processing Record 38 of Set 4 | falavarjan
# Processing Record 39 of Set 4 | tignoan
# Processing Record 40 of Set 4 | qaanaaq
# Processing Record 41 of Set 4 | nikolskoye
# Processing Record 42 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 43 of Set 4 | isla vista
# Processing Record 44 of Set 4 | revelstoke
# Processing Record 45 of Set 4 | santiago del estero
# Processing Record 46 of Set 4 | aklavik
# Processing Record 47 of Set 4 | mizan teferi
# Processing Record 48 of Set 4 | kalabo
# Processing Record 49 of Set 4 | yulara
# Processing Record 50 of Set 4 | jurm
# Processing Record 1 of Set 5 | muriti
# Processing Record 2 of Set 5 | torbay
# Processing Record 3 of Set 5 | portland
# Processing Record 4 of Set 5 | marawi
# Processing Record 5 of Set 5 | kuryk
# Processing Record 6 of Set 5 | brainerd
# Processing Record 7 of Set 5 | severo-kurilsk
# Processing Record 8 of Set 5 | castro
# Processing Record 9 of Set 5 | tessalit
# Processing Record 10 of Set 5 | kinanah
# City not found. Skipping...
# Processing Record 11 of Set 5 | bluefield
# Processing Record 12 of Set 5 | saint anthony
# Processing Record 13 of Set 5 | hovd
# Processing Record 14 of Set 5 | saint-pierre
# Processing Record 15 of Set 5 | souillac
# Processing Record 16 of Set 5 | kalengwa
# Processing Record 17 of Set 5 | amahai
# Processing Record 18 of Set 5 | vanimo
# Processing Record 19 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 5 | mongo
# Processing Record 21 of Set 5 | chapais
# Processing Record 22 of Set 5 | todi
# Processing Record 23 of Set 5 | terrace
# Processing Record 24 of Set 5 | avera
# Processing Record 25 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 5 | sao filipe
# Processing Record 27 of Set 5 | faya
# Processing Record 28 of Set 5 | milkovo
# Processing Record 29 of Set 5 | ulaanbaatar
# Processing Record 30 of Set 5 | carnot
# Processing Record 31 of Set 5 | new norfolk
# Processing Record 32 of Set 5 | apomu
# Processing Record 33 of Set 5 | hornepayne
# Processing Record 34 of Set 5 | clyde river
# Processing Record 35 of Set 5 | montgomery
# Processing Record 36 of Set 5 | port elizabeth
# Processing Record 37 of Set 5 | bar harbor
# Processing Record 38 of Set 5 | makakilo city
# Processing Record 39 of Set 5 | itapirapua
# Processing Record 40 of Set 5 | monterey
# Processing Record 41 of Set 5 | cervo
# Processing Record 42 of Set 5 | springfield
# Processing Record 43 of Set 5 | port lincoln
# Processing Record 44 of Set 5 | velyka kisnytsya
# City not found. Skipping...
# Processing Record 45 of Set 5 | turayf
# Processing Record 46 of Set 5 | yei
# Processing Record 47 of Set 5 | kaeo
# Processing Record 48 of Set 5 | rio gallegos
# Processing Record 49 of Set 5 | ritchie
# Processing Record 50 of Set 5 | chaa-khol
# City not found. Skipping...
# Processing Record 1 of Set 6 | naze
# Processing Record 2 of Set 6 | gat
# Processing Record 3 of Set 6 | oranjestad
# Processing Record 4 of Set 6 | warwick
# Processing Record 5 of Set 6 | kang
# Processing Record 6 of Set 6 | touros
# Processing Record 7 of Set 6 | sansai
# City not found. Skipping...
# Processing Record 8 of Set 6 | jalu
# Processing Record 9 of Set 6 | snezhnogorsk
# Processing Record 10 of Set 6 | olafsvik
# Processing Record 11 of Set 6 | plouzane
# Processing Record 12 of Set 6 | bairnsdale
# Processing Record 13 of Set 6 | elat
# Processing Record 14 of Set 6 | santiago
# Processing Record 15 of Set 6 | karoi
# Processing Record 16 of Set 6 | norman wells
# Processing Record 17 of Set 6 | geresk
# City not found. Skipping...
# Processing Record 18 of Set 6 | qinggang
# Processing Record 19 of Set 6 | sur
# Processing Record 20 of Set 6 | daru
# Processing Record 21 of Set 6 | chulman
# Processing Record 22 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 6 | bend
# Processing Record 24 of Set 6 | roanoke rapids
# Processing Record 25 of Set 6 | lagos
# Processing Record 26 of Set 6 | faanui
# Processing Record 27 of Set 6 | calbuco
# Processing Record 28 of Set 6 | nemuro
# Processing Record 29 of Set 6 | oneonta
# Processing Record 30 of Set 6 | glenwood springs
# Processing Record 31 of Set 6 | lavrentiya
# Processing Record 32 of Set 6 | sao joao da barra
# Processing Record 33 of Set 6 | half moon bay
# Processing Record 34 of Set 6 | vestmannaeyjar
# Processing Record 35 of Set 6 | samarai
# Processing Record 36 of Set 6 | baruun-urt
# Processing Record 37 of Set 6 | kuytun
# Processing Record 38 of Set 6 | tuatapere
# Processing Record 39 of Set 6 | shingu
# Processing Record 40 of Set 6 | kosikha
# Processing Record 41 of Set 6 | esperance
# Processing Record 42 of Set 6 | port keats
# Processing Record 43 of Set 6 | sao geraldo do araguaia
# Processing Record 44 of Set 6 | copalau
# Processing Record 45 of Set 6 | ilulissat
# Processing Record 46 of Set 6 | georgetown
# Processing Record 47 of Set 6 | port augusta
# Processing Record 48 of Set 6 | broken hill
# Processing Record 49 of Set 6 | bukachacha
# Processing Record 50 of Set 6 | kununurra
# Processing Record 1 of Set 7 | yokadouma
# Processing Record 2 of Set 7 | nome
# Processing Record 3 of Set 7 | talara
# Processing Record 4 of Set 7 | yatou
# Processing Record 5 of Set 7 | suyo
# Processing Record 6 of Set 7 | teya
# Processing Record 7 of Set 7 | taoudenni
# Processing Record 8 of Set 7 | sambava
# Processing Record 9 of Set 7 | polunochnoye
# Processing Record 10 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 11 of Set 7 | venta
# Processing Record 12 of Set 7 | korla
# Processing Record 13 of Set 7 | cowra
# Processing Record 14 of Set 7 | imamoglu
# Processing Record 15 of Set 7 | avarua
# Processing Record 16 of Set 7 | bontang
# Processing Record 17 of Set 7 | tokur
# Processing Record 18 of Set 7 | franklin
# Processing Record 19 of Set 7 | abbeville
# Processing Record 20 of Set 7 | zaozerne
# Processing Record 21 of Set 7 | talnakh
# Processing Record 22 of Set 7 | manokwari
# Processing Record 23 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 7 | pinhao
# Processing Record 25 of Set 7 | belyy yar
# Processing Record 26 of Set 7 | beloha
# Processing Record 27 of Set 7 | waitara
# Processing Record 28 of Set 7 | ubrique
# Processing Record 29 of Set 7 | caluquembe
# Processing Record 30 of Set 7 | atar
# Processing Record 31 of Set 7 | mbandaka
# Processing Record 32 of Set 7 | nanortalik
# Processing Record 33 of Set 7 | wuchang
# Processing Record 34 of Set 7 | rio cuarto
# Processing Record 35 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 7 | leo
# Processing Record 37 of Set 7 | nyurba
# Processing Record 38 of Set 7 | gashua
# Processing Record 39 of Set 7 | hami
# Processing Record 40 of Set 7 | contamana
# Processing Record 41 of Set 7 | atuona
# Processing Record 42 of Set 7 | bulungu
# Processing Record 43 of Set 7 | luanda
# Processing Record 44 of Set 7 | chimbote
# Processing Record 45 of Set 7 | mineros
# Processing Record 46 of Set 7 | zitiste
# Processing Record 47 of Set 7 | nantucket
# Processing Record 48 of Set 7 | birin
# Processing Record 49 of Set 7 | bahraich
# Processing Record 50 of Set 7 | saint-augustin
# Processing Record 1 of Set 8 | kamir
# Processing Record 2 of Set 8 | padang
# Processing Record 3 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 8 | plastun
# Processing Record 5 of Set 8 | mendahara
# City not found. Skipping...
# Processing Record 6 of Set 8 | saskylakh
# Processing Record 7 of Set 8 | northam
# Processing Record 8 of Set 8 | mahebourg
# Processing Record 9 of Set 8 | swan hill
# Processing Record 10 of Set 8 | westfield
# Processing Record 11 of Set 8 | geraldton
# Processing Record 12 of Set 8 | barga
# Processing Record 13 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 14 of Set 8 | najran
# Processing Record 15 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 16 of Set 8 | vwawa
# Processing Record 17 of Set 8 | oda
# Processing Record 18 of Set 8 | leningradskiy
# Processing Record 19 of Set 8 | tura
# Processing Record 20 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 21 of Set 8 | flagstaff
# Processing Record 22 of Set 8 | kichera
# Processing Record 23 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 24 of Set 8 | north bend
# Processing Record 25 of Set 8 | namibe
# Processing Record 26 of Set 8 | atasu
# Processing Record 27 of Set 8 | kholodnyy
# Processing Record 28 of Set 8 | westerland
# Processing Record 29 of Set 8 | hamilton
# Processing Record 30 of Set 8 | nuuk
# Processing Record 31 of Set 8 | chifeng
# Processing Record 32 of Set 8 | west wendover
# Processing Record 33 of Set 8 | lushunkou
# City not found. Skipping...
# Processing Record 34 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 8 | kysyl-syr
# Processing Record 36 of Set 8 | aykhal
# Processing Record 37 of Set 8 | pasni
# Processing Record 38 of Set 8 | waddan
# Processing Record 39 of Set 8 | alihe
# Processing Record 40 of Set 8 | kiparissia
# City not found. Skipping...
# Processing Record 41 of Set 8 | teeli
# Processing Record 42 of Set 8 | sal rei
# Processing Record 43 of Set 8 | almaznyy
# Processing Record 44 of Set 8 | tayu
# Processing Record 45 of Set 8 | sala consilina
# Processing Record 46 of Set 8 | oussouye
# Processing Record 47 of Set 8 | fairbanks
# Processing Record 48 of Set 8 | xifeng
# Processing Record 49 of Set 8 | hay river
# Processing Record 50 of Set 8 | ancud
# Processing Record 1 of Set 9 | alyangula
# Processing Record 2 of Set 9 | shimoda
# Processing Record 3 of Set 9 | mogadishu
# Processing Record 4 of Set 9 | vostok
# Processing Record 5 of Set 9 | ouallam
# Processing Record 6 of Set 9 | troitsk
# Processing Record 7 of Set 9 | ponta delgada
# Processing Record 8 of Set 9 | pandamatenga
# Processing Record 9 of Set 9 | san vicente
# Processing Record 10 of Set 9 | baykit
# Processing Record 11 of Set 9 | slonim
# Processing Record 12 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 13 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 14 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 9 | kolvereid
# Processing Record 16 of Set 9 | vardo
# Processing Record 17 of Set 9 | estelle
# Processing Record 18 of Set 9 | varhaug
# Processing Record 19 of Set 9 | chikoy
# City not found. Skipping...
# Processing Record 20 of Set 9 | carutapera
# Processing Record 21 of Set 9 | cabedelo
# Processing Record 22 of Set 9 | grand gaube
# Processing Record 23 of Set 9 | dawlatabad
# Processing Record 24 of Set 9 | camacupa
# Processing Record 25 of Set 9 | kalaikunda
# Processing Record 26 of Set 9 | magnolia
# Processing Record 27 of Set 9 | pizhanka
# Processing Record 28 of Set 9 | svetlaya
# Processing Record 29 of Set 9 | tigil
# Processing Record 30 of Set 9 | japura
# Processing Record 31 of Set 9 | maldonado
# Processing Record 32 of Set 9 | marsala
# Processing Record 33 of Set 9 | cam ranh
# Processing Record 34 of Set 9 | canaries
# Processing Record 35 of Set 9 | bella union
# Processing Record 36 of Set 9 | basco
# Processing Record 37 of Set 9 | punta alta
# Processing Record 38 of Set 9 | bure
# Processing Record 39 of Set 9 | kinsale
# Processing Record 40 of Set 9 | ningxiang
# Processing Record 41 of Set 9 | praya
# Processing Record 42 of Set 9 | ingham
# Processing Record 43 of Set 9 | paragominas
# Processing Record 44 of Set 9 | kutum
# Processing Record 45 of Set 9 | wilmington
# Processing Record 46 of Set 9 | lima
# Processing Record 47 of Set 9 | gorin
# Processing Record 48 of Set 9 | syntul
# Processing Record 49 of Set 9 | guerrero negro
# Processing Record 50 of Set 9 | vargem grande
# Processing Record 1 of Set 10 | bull savanna
# Processing Record 2 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 3 of Set 10 | kahului
# Processing Record 4 of Set 10 | haines junction
# Processing Record 5 of Set 10 | wladyslawowo
# Processing Record 6 of Set 10 | karratha
# Processing Record 7 of Set 10 | acapulco
# Processing Record 8 of Set 10 | atocha
# Processing Record 9 of Set 10 | krasnoselkup
# Processing Record 10 of Set 10 | boa vista
# Processing Record 11 of Set 10 | mareeba
# Processing Record 12 of Set 10 | biltine
# Processing Record 13 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 14 of Set 10 | rock hill
# Processing Record 15 of Set 10 | myaundzha
# Processing Record 16 of Set 10 | salalah
# Processing Record 17 of Set 10 | nador
# Processing Record 18 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 10 | maamba
# Processing Record 20 of Set 10 | aksu
# Processing Record 21 of Set 10 | broome
# Processing Record 22 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 10 | awbari
# Processing Record 24 of Set 10 | santa isabel do rio negro
# Processing Record 25 of Set 10 | bereda
# Processing Record 26 of Set 10 | narsaq
# Processing Record 27 of Set 10 | saint-pacome
# City not found. Skipping...
# Processing Record 28 of Set 10 | vila franca do campo
# Processing Record 29 of Set 10 | port-gentil
# Processing Record 30 of Set 10 | puerto escondido
# Processing Record 31 of Set 10 | zastron
# Processing Record 32 of Set 10 | husavik
# Processing Record 33 of Set 10 | cazones
# Processing Record 34 of Set 10 | savelugu
# Processing Record 35 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 10 | margate
# Processing Record 37 of Set 10 | comodoro rivadavia
# Processing Record 38 of Set 10 | labuhan
# Processing Record 39 of Set 10 | mandalgovi
# Processing Record 40 of Set 10 | ilo
# Processing Record 41 of Set 10 | nouadhibou
# Processing Record 42 of Set 10 | quatre cocos
# Processing Record 43 of Set 10 | tarauaca
# Processing Record 44 of Set 10 | pangkalanbuun
# Processing Record 45 of Set 10 | mehamn
# Processing Record 46 of Set 10 | kindia
# Processing Record 47 of Set 10 | san cristobal
# Processing Record 48 of Set 10 | rota
# Processing Record 49 of Set 10 | amga
# Processing Record 50 of Set 10 | hualmay
# Processing Record 1 of Set 11 | kasongo-lunda
# Processing Record 2 of Set 11 | chiredzi
# Processing Record 3 of Set 11 | rio claro
# Processing Record 4 of Set 11 | barcelos
# Processing Record 5 of Set 11 | lakes entrance
# Processing Record 6 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 7 of Set 11 | puerto cabezas
# Processing Record 8 of Set 11 | nabire
# Processing Record 9 of Set 11 | zenzeli
# Processing Record 10 of Set 11 | san quintin
# Processing Record 11 of Set 11 | chokurdakh
# Processing Record 12 of Set 11 | san patricio
# Processing Record 13 of Set 11 | bambanglipuro
# Processing Record 14 of Set 11 | scarborough
# Processing Record 15 of Set 11 | sao jose de ribamar
# Processing Record 16 of Set 11 | dukat
# Processing Record 17 of Set 11 | bafra
# Processing Record 18 of Set 11 | bud
# Processing Record 19 of Set 11 | dong xoai
# Processing Record 20 of Set 11 | chipiona
# Processing Record 21 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 22 of Set 11 | tukrah
# Processing Record 23 of Set 11 | kuopio
# Processing Record 24 of Set 11 | ossora
# Processing Record 25 of Set 11 | constantine
# Processing Record 26 of Set 11 | pitimbu
# Processing Record 27 of Set 11 | maniitsoq
# Processing Record 28 of Set 11 | houma
# Processing Record 29 of Set 11 | talavera de la reina
# Processing Record 30 of Set 11 | emborion
# Processing Record 31 of Set 11 | panormos
# Processing Record 32 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 33 of Set 11 | coruripe
# Processing Record 34 of Set 11 | dzilam gonzalez
# Processing Record 35 of Set 11 | tinjah
# City not found. Skipping...
# Processing Record 36 of Set 11 | nevsehir
# Processing Record 37 of Set 11 | zaysan
# Processing Record 38 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 39 of Set 11 | nizwa
# Processing Record 40 of Set 11 | kamenka
# Processing Record 41 of Set 11 | dambulla
# Processing Record 42 of Set 11 | sola
# Processing Record 43 of Set 11 | palu
# Processing Record 44 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 45 of Set 11 | kathu
# Processing Record 46 of Set 11 | saldanha
# Processing Record 47 of Set 11 | severo-yeniseyskiy
# Processing Record 48 of Set 11 | la ronge
# Processing Record 49 of Set 11 | raga
# Processing Record 50 of Set 11 | russellville
# Processing Record 1 of Set 12 | jiangyou
# Processing Record 2 of Set 12 | mikhaylovka
# Processing Record 3 of Set 12 | phalaborwa
# Processing Record 4 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 5 of Set 12 | biak
# Processing Record 6 of Set 12 | bilma
# Processing Record 7 of Set 12 | marsa matruh
# Processing Record 8 of Set 12 | dzhebariki-khaya
# Processing Record 9 of Set 12 | asfi
# Processing Record 10 of Set 12 | diego de almagro
# Processing Record 11 of Set 12 | kirakira
# Processing Record 12 of Set 12 | nioro
# Processing Record 13 of Set 12 | kungurtug
# Processing Record 14 of Set 12 | zaraza
# Processing Record 15 of Set 12 | alcazar de san juan
# Processing Record 16 of Set 12 | bone
# Processing Record 17 of Set 12 | dolores
# Processing Record 18 of Set 12 | klaksvik
# Processing Record 19 of Set 12 | constitucion
# Processing Record 20 of Set 12 | muros
# Processing Record 21 of Set 12 | vamospercs
# Processing Record 22 of Set 12 | aasiaat
# Processing Record 23 of Set 12 | shakawe
# Processing Record 24 of Set 12 | srednekolymsk
# Processing Record 25 of Set 12 | tiarei
# Processing Record 26 of Set 12 | te anau
# Processing Record 27 of Set 12 | uvira
# Processing Record 28 of Set 12 | moose factory
# Processing Record 29 of Set 12 | antofagasta
# Processing Record 30 of Set 12 | whitehorse
# Processing Record 31 of Set 12 | muswellbrook
# Processing Record 32 of Set 12 | chiguayante
# Processing Record 33 of Set 12 | poum
# Processing Record 34 of Set 12 | lata
# Processing Record 35 of Set 12 | fort nelson
# Processing Record 36 of Set 12 | tarakan
# Processing Record 37 of Set 12 | uberaba
# Processing Record 38 of Set 12 | balkhash
# Processing Record 39 of Set 12 | keti bandar
# Processing Record 40 of Set 12 | luwuk
# Processing Record 41 of Set 12 | oranjemund
# Processing Record 42 of Set 12 | cidreira
# Processing Record 43 of Set 12 | araguaina
# Processing Record 44 of Set 12 | viedma
# Processing Record 45 of Set 12 | laguna
# Processing Record 46 of Set 12 | verkhoyansk
# Processing Record 47 of Set 12 | barra do garcas
# Processing Record 48 of Set 12 | gravdal
# Processing Record 49 of Set 12 | kavieng
# Processing Record 50 of Set 12 | coquimbo
# Processing Record 1 of Set 13 | ordynskoye
# Processing Record 2 of Set 13 | katsuura
# Processing Record 3 of Set 13 | petrokamenskoye
# Processing Record 4 of Set 13 | taltal
# Processing Record 5 of Set 13 | vazante
# Processing Record 6 of Set 13 | kofele
# Processing Record 7 of Set 13 | pitkyaranta
# Processing Record 8 of Set 13 | maraa
# Processing Record 9 of Set 13 | bangangte
# Processing Record 10 of Set 13 | shinshiro
# Processing Record 11 of Set 13 | havoysund
# Processing Record 12 of Set 13 | vysokogornyy
# Processing Record 13 of Set 13 | muncar
# Processing Record 14 of Set 13 | jardim do serido
# Processing Record 15 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 13 | nishihara
# Processing Record 17 of Set 13 | oktyabrskoye
# Processing Record 18 of Set 13 | santa lucia
# Processing Record 19 of Set 13 | ustrzyki dolne
# Processing Record 20 of Set 13 | xichang
# Processing Record 21 of Set 13 | katherine
# Processing Record 22 of Set 13 | manali
# Processing Record 23 of Set 13 | kemi
# Processing Record 24 of Set 13 | ambilobe
# Processing Record 25 of Set 13 | khorixas
# Processing Record 26 of Set 13 | okato
# Processing Record 27 of Set 13 | sao joao batista
# Processing Record 28 of Set 13 | puri
# Processing Record 29 of Set 13 | ranong
# Processing Record 30 of Set 13 | xining
# Processing Record 31 of Set 13 | mackay
# Processing Record 32 of Set 13 | victor harbor
# Processing Record 33 of Set 13 | qingdao
# Processing Record 34 of Set 13 | itaituba
# Processing Record 35 of Set 13 | rawson
# Processing Record 36 of Set 13 | liusha
# Processing Record 37 of Set 13 | sindor
# Processing Record 38 of Set 13 | gigmoto
# Processing Record 39 of Set 13 | kachkanar
# Processing Record 40 of Set 13 | disna
# Processing Record 41 of Set 13 | roma
# Processing Record 42 of Set 13 | batemans bay
# Processing Record 43 of Set 13 | iglesias
# Processing Record 44 of Set 13 | longyearbyen
# Processing Record 45 of Set 13 | teguldet
# Processing Record 46 of Set 13 | acarau
# Processing Record 47 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 48 of Set 13 | mazabuka
# Processing Record 49 of Set 13 | cayeli
# Processing Record 50 of Set 13 | mitsamiouli
# Processing Record 1 of Set 14 | posse
# Processing Record 2 of Set 14 | buta
# Processing Record 3 of Set 14 | san rafael
# Processing Record 4 of Set 14 | halifax
# Processing Record 5 of Set 14 | tambilil
# Processing Record 6 of Set 14 | grindavik
# Processing Record 7 of Set 14 | mount gambier
# Processing Record 8 of Set 14 | kapuskasing
# Processing Record 9 of Set 14 | huanren
# Processing Record 10 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 11 of Set 14 | vila velha
# Processing Record 12 of Set 14 | kenai
# Processing Record 13 of Set 14 | iranshahr
# Processing Record 14 of Set 14 | jutai
# Processing Record 15 of Set 14 | nicoya
# Processing Record 16 of Set 14 | tomohon
# Processing Record 17 of Set 14 | alice springs
# Processing Record 18 of Set 14 | puurmani
# Processing Record 19 of Set 14 | kuvshinovo
# Processing Record 20 of Set 14 | sabzevar
# Processing Record 21 of Set 14 | porto empedocle
# Processing Record 22 of Set 14 | ekibastuz
# Processing Record 23 of Set 14 | bellefontaine
# Processing Record 24 of Set 14 | paullo
# Processing Record 25 of Set 14 | necochea
# Processing Record 26 of Set 14 | keuruu
# Processing Record 27 of Set 14 | marsabit
# Processing Record 28 of Set 14 | tevriz
# Processing Record 29 of Set 14 | alekseyevsk
# Processing Record 30 of Set 14 | candido de abreu
# Processing Record 31 of Set 14 | allapalli
# Processing Record 32 of Set 14 | chapleau
# Processing Record 33 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 14 | hailun
# Processing Record 35 of Set 14 | bonoua
# Processing Record 36 of Set 14 | tabialan
# City not found. Skipping...
# Processing Record 37 of Set 14 | shishou
# Processing Record 38 of Set 14 | liwale
# Processing Record 39 of Set 14 | nisia floresta
# Processing Record 40 of Set 14 | mount pleasant
# Processing Record 41 of Set 14 | leh
# Processing Record 42 of Set 14 | jos
# Processing Record 43 of Set 14 | visby
# Processing Record 44 of Set 14 | wasilla
# Processing Record 45 of Set 14 | cockburn town
# Processing Record 46 of Set 14 | asosa
# Processing Record 47 of Set 14 | valdivia
# Processing Record 48 of Set 14 | luganville
# Processing Record 49 of Set 14 | virtsu
# Processing Record 50 of Set 14 | port macquarie
# Processing Record 1 of Set 15 | lucapa
# Processing Record 2 of Set 15 | alghero
# Processing Record 3 of Set 15 | pandan
# Processing Record 4 of Set 15 | kulhudhuffushi
# Processing Record 5 of Set 15 | saint-francois
# Processing Record 6 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 7 of Set 15 | port moresby
# Processing Record 8 of Set 15 | salinopolis
# Processing Record 9 of Set 15 | boromo
# Processing Record 10 of Set 15 | urusha
# Processing Record 11 of Set 15 | qeshm
# Processing Record 12 of Set 15 | acajutla
# Processing Record 13 of Set 15 | sinnamary
# Processing Record 14 of Set 15 | davila
# Processing Record 15 of Set 15 | luyang
# Processing Record 16 of Set 15 | hobbs
# Processing Record 17 of Set 15 | morro bay
# Processing Record 18 of Set 15 | binga
# Processing Record 19 of Set 15 | katsiveli
# City not found. Skipping...
# Processing Record 20 of Set 15 | horta
# Processing Record 21 of Set 15 | jiaonan
# Processing Record 22 of Set 15 | puerto quijarro
# Processing Record 23 of Set 15 | urdoma
# Processing Record 24 of Set 15 | tapaua
# City not found. Skipping...
# Processing Record 25 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 15 | bakel
# Processing Record 27 of Set 15 | bacolod
# Processing Record 28 of Set 15 | buchanan
# Processing Record 29 of Set 15 | asahikawa
# Processing Record 30 of Set 15 | hurghada
# Processing Record 31 of Set 15 | berea
# Processing Record 32 of Set 15 | santa engracia
# Processing Record 33 of Set 15 | bhatapara
# Processing Record 34 of Set 15 | zamania
# Processing Record 35 of Set 15 | cozumel
# Processing Record 36 of Set 15 | kendal
# Processing Record 37 of Set 15 | petropolis
# Processing Record 38 of Set 15 | fabianhaza
# City not found. Skipping...
# Processing Record 39 of Set 15 | lasa
# Processing Record 40 of Set 15 | veraval
# Processing Record 41 of Set 15 | cooma
# Processing Record 42 of Set 15 | bababe
# City not found. Skipping...
# Processing Record 43 of Set 15 | stornoway
# Processing Record 44 of Set 15 | zyryanka
# Processing Record 45 of Set 15 | thinadhoo
# Processing Record 46 of Set 15 | shawnee
# Processing Record 47 of Set 15 | sibolga
# Processing Record 48 of Set 15 | baghdad
# Processing Record 49 of Set 15 | leca da palmeira
# Processing Record 50 of Set 15 | ambunti
# Processing Record 1 of Set 16 | arman
# Processing Record 2 of Set 16 | ouadda
# Processing Record 3 of Set 16 | khani
# Processing Record 4 of Set 16 | slave lake
# Processing Record 5 of Set 16 | port hardy
# Processing Record 6 of Set 16 | maningrida
# Processing Record 7 of Set 16 | ust-tsilma
# Processing Record 8 of Set 16 | inongo
# Processing Record 9 of Set 16 | vieste
# Processing Record 10 of Set 16 | zabol
# Processing Record 11 of Set 16 | aranos
# Processing Record 12 of Set 16 | new bedford
# Processing Record 13 of Set 16 | kalomo
# City not found. Skipping...
# Processing Record 14 of Set 16 | mering
# Processing Record 15 of Set 16 | sokoni
# Processing Record 16 of Set 16 | kamphaeng phet
# Processing Record 17 of Set 16 | rio verde de mato grosso
# Processing Record 18 of Set 16 | rumford
# Processing Record 19 of Set 16 | sept-iles
# Processing Record 20 of Set 16 | jucas
# Processing Record 21 of Set 16 | charters towers
# --------------------
# Data Retrieval Complete
# --------------------

# %%
len(city_data)
# Out:
# 703

# %%
# convert list of dictionaries to a pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp Current Description  \
# 0       bengkulu  -3.8004  102.2655     75.74     overcast clouds
# 1         barrow  71.2906 -156.7887     -3.98                haze
# 2           knin  44.0439   16.2000     45.59     overcast clouds
# 3  pacific grove  36.6177 -121.9166     56.88           clear sky
# 4        yenagoa   4.9247    6.2642     78.78    scattered clouds
# 5         albany  42.6001  -73.9662     37.31     overcast clouds
# 6        ushuaia -54.8000  -68.3000     46.06       broken clouds
# 7    east london -33.0153   27.9116     79.02     overcast clouds
# 8          adrar  20.5022  -10.0711     66.49     overcast clouds
# 9    honningsvag  70.9821   25.9704     28.49     overcast clouds
#
#    Rain (inches)  Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0            0.0            0.0        88         100        3.02      ID
# 1            0.0            0.0        77          90        3.44      US
# 2            0.0            0.0        93          97        6.40      HR
# 3            0.0            0.0        68           1        5.01      US
# 4            0.0            0.0        89          33        4.25      NG
# 5            0.0            0.0        79          88        2.77      US
# 6            0.0            0.0        87          75       16.11      AR
# 7            0.0            0.0        54          96       11.65      ZA
# 8            0.0            0.0        14          97       10.80      MR
# 9            0.0            0.0        73         100       15.23      NO

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description',
#        'Rain (inches)', 'Snow (inches)', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country'],
#       dtype='object')

# %%
new_column_order = sorted(city_data_df.columns.tolist())
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                          City  Cloudiness Country Current Description  \
# 0                    bengkulu         100      ID     overcast clouds
# 1                      barrow          90      US                haze
# 2                        knin          97      HR     overcast clouds
# 3               pacific grove           1      US           clear sky
# 4                     yenagoa          33      NG    scattered clouds
# ..                        ...         ...     ...                 ...
# 698  rio verde de mato grosso          91      BR     overcast clouds
# 699                   rumford         100      US     overcast clouds
# 700                 sept-iles          90      CA          light snow
# 701                     jucas          15      BR          few clouds
# 702           charters towers           2      AU           clear sky
#
#      Humidity      Lat       Lng  Max Temp  Rain (inches)  Snow (inches)  \
# 0          88  -3.8004  102.2655     75.74            0.0            0.0
# 1          77  71.2906 -156.7887     -3.98            0.0            0.0
# 2          93  44.0439   16.2000     45.59            0.0            0.0
# 3          68  36.6177 -121.9166     56.88            0.0            0.0
# 4          89   4.9247    6.2642     78.78            0.0            0.0
# ..        ...      ...       ...       ...            ...            ...
# 698        47 -18.9181  -54.8442     79.43            0.0            0.0
# 699        86  44.5537  -70.5509     27.95            0.0            0.0
# 700        91  50.2001  -66.3821     16.05            0.0            0.0
# 701        58  -6.5253  -39.5275     81.21            0.0            0.0
# 702        33 -20.1000  146.2667     88.09            0.0            0.0
#
#      Wind Speed
# 0          3.02
# 1          3.44
# 2          6.40
# 3          5.01
# 4          4.25
# ..          ...
# 698        6.78
# 699        1.25
# 700        5.75
# 701        1.12
# 702        1.92
#
# [703 rows x 11 columns]

# %%
city_data_df.dtypes
# Out:
# City                    object
# Cloudiness               int64
# Country                 object
# Current Description     object
# Humidity                 int64
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Rain (inches)          float64
# Snow (inches)          float64
# Wind Speed             float64
# dtype: object

# %%
raining_cities = city_data_df.loc[city_data_df["Rain (inches)"] > 0]
raining_cities.head(10)
# Out:
#              City  Cloudiness Country   Current Description  Humidity  \
# 22        vilhena          82      BR  heavy intensity rain        95
# 29       lorengau         100      PG         moderate rain        86
# 65       pozzallo         100      IT            light rain        88
# 71          alofi          58      NU            light rain        65
# 72          kapaa          90      US         moderate rain        84
# 83   kruisfontein          18      ZA            light rain        95
# 94          sitka          90      US            light rain        86
# 112     namatanai          97      PG            light rain        69
# 117      wakkanai          75      JP         moderate rain        76
# 127         buala         100      SB         moderate rain        81
#
#          Lat       Lng  Max Temp  Rain (inches)  Snow (inches)  Wind Speed
# 22  -12.7406  -60.1458     71.08           4.21           4.21        2.26
# 29   -2.0226  147.2712     81.73           2.30           2.30       16.87
# 65   36.7305   14.8499     56.05           0.34           0.34       30.87
# 71  -19.0595 -169.9187     84.09           0.62           0.62        9.22
# 72   22.0752 -159.3190     80.58           1.27           1.27        1.01
# 83  -34.0033   24.7314     67.89           0.11           0.11        8.41
# 94   57.0531 -135.3300     33.69           0.51           0.51        5.75
# 112  -3.6667  152.4333     85.46           0.10           0.10        7.05
# 117  45.4094  141.6739     44.58           1.15           1.15       12.66
# 127  -8.1450  159.5921     83.21           1.60           1.60        9.84

# %%
snowing_cities = city_data_df.loc[city_data_df["Snow (inches)"] > 0]
snowing_cities.head(10)
# Out:
#              City  Cloudiness Country   Current Description  Humidity  \
# 22        vilhena          82      BR  heavy intensity rain        95
# 29       lorengau         100      PG         moderate rain        86
# 65       pozzallo         100      IT            light rain        88
# 71          alofi          58      NU            light rain        65
# 72          kapaa          90      US         moderate rain        84
# 83   kruisfontein          18      ZA            light rain        95
# 94          sitka          90      US            light rain        86
# 112     namatanai          97      PG            light rain        69
# 117      wakkanai          75      JP         moderate rain        76
# 127         buala         100      SB         moderate rain        81
#
#          Lat       Lng  Max Temp  Rain (inches)  Snow (inches)  Wind Speed
# 22  -12.7406  -60.1458     71.08           4.21           4.21        2.26
# 29   -2.0226  147.2712     81.73           2.30           2.30       16.87
# 65   36.7305   14.8499     56.05           0.34           0.34       30.87
# 71  -19.0595 -169.9187     84.09           0.62           0.62        9.22
# 72   22.0752 -159.3190     80.58           1.27           1.27        1.01
# 83  -34.0033   24.7314     67.89           0.11           0.11        8.41
# 94   57.0531 -135.3300     33.69           0.51           0.51        5.75
# 112  -3.6667  152.4333     85.46           0.10           0.10        7.05
# 117  45.4094  141.6739     44.58           1.15           1.15       12.66
# 127  -8.1450  159.5921     83.21           1.60           1.60        9.84

# %%
# Create the output file (CSV)
output_data_file = "Weather_Data/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
